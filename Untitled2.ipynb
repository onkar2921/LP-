# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv('sales.csv',encoding='ISO-8859-1')

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %%
df=df.drop(columns=["ORDERNUMBER", "ORDERLINENUMBER", "ORDERDATE", "QTR_ID", "MONTH_ID", "YEAR_ID", "MSRP", "CUSTOMERNAME", "PHONE", "ADDRESSLINE1", "ADDRESSLINE2" ,"POSTALCODE", "STATE", "TERRITORY", "CONTACTLASTNAME", "CONTACTFIRSTNAME"
])

# %%
df
# Out:
#       QUANTITYORDERED  PRICEEACH    SALES    STATUS  PRODUCTLINE PRODUCTCODE  \
# 0                  30      95.70  2871.00   Shipped  Motorcycles    S10_1678
# 1                  34      81.35  2765.90   Shipped  Motorcycles    S10_1678
# 2                  41      94.74  3884.34   Shipped  Motorcycles    S10_1678
# 3                  45      83.26  3746.70   Shipped  Motorcycles    S10_1678
# 4                  49     100.00  5205.27   Shipped  Motorcycles    S10_1678
# ...               ...        ...      ...       ...          ...         ...
# 2818               20     100.00  2244.40   Shipped        Ships    S72_3212
# 2819               29     100.00  3978.51   Shipped        Ships    S72_3212
# 2820               43     100.00  5417.57  Resolved        Ships    S72_3212
# 2821               34      62.24  2116.16   Shipped        Ships    S72_3212
# 2822               47      65.52  3079.44   On Hold        Ships    S72_3212
#
#                CITY  COUNTRY DEALSIZE
# ...

# %%
df.isna().sum()
# Out:
# QUANTITYORDERED    0
# PRICEEACH          0
# SALES              0
# STATUS             0
# PRODUCTLINE        0
# PRODUCTCODE        0
# CITY               0
# COUNTRY            0
# DEALSIZE           0
# dtype: int64

# %%
df=df.dropna()

# %%
df.isna().sum()
# Out:
# QUANTITYORDERED    0
# PRICEEACH          0
# SALES              0
# STATUS             0
# PRODUCTLINE        0
# PRODUCTCODE        0
# CITY               0
# COUNTRY            0
# DEALSIZE           0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
en=LabelEncoder()

# %%
df['STATUS']=en.fit_transform(df['STATUS'])
df['PRODUCTLINE']=en.fit_transform(df['PRODUCTLINE'])
df['PRODUCTCODE']=en.fit_transform(df['PRODUCTCODE'])
df['CITY']=en.fit_transform(df['CITY'])
df['COUNTRY']=en.fit_transform(df['COUNTRY'])
df['DEALSIZE']=en.fit_transform(df['DEALSIZE'])

# %%
df.head()
# Out:
#    QUANTITYORDERED  PRICEEACH    SALES  STATUS  PRODUCTLINE  PRODUCTCODE  \
# 0               30      95.70  2871.00       5            1            0
# 1               34      81.35  2765.90       5            1            0
# 2               41      94.74  3884.34       5            1            0
# 3               45      83.26  3746.70       5            1            0
# 4               49     100.00  5205.27       5            1            0
#
#    CITY  COUNTRY  DEALSIZE
# 0    42       18         2
# 1    56        6         2
# 2    52        6         1
# 3    53       18         1
# 4    59       18         1

# %%
from sklearn.cluster import KMeans

# %%
In the context of K-Means clustering, WCSS stands for Within-Cluster Sum of Squares. It measures the sum of squared distances between each data point and the centroid of its assigned cluster. WCSS is used as a measure of how tightly the data points are clustered around the centroids and is calculated for each potential number of clusters (k) when determining the optimal number of clusters.

# %%
wcss=[]
for i in range(1,21):
    km=KMeans(n_clusters=i)
    km.fit_predict(df)
    wcss.append(km.inertia_)
# Out:
# C:\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
wcss
# Out:
# [9578967881.541874,
#  3326270732.2667003,
#  1733375733.004341,
#  1044071154.8706574,
#  716461909.5870832,
#  515647306.40214056,
#  387922428.9475383,
#  299051912.45018286,
#  235156690.2039126,
#  191979603.17755598,
#  159495946.32718033,
#  134607684.1126512,
#  115289446.66253534,
#  100473253.74576297,
#  88922549.88910826,
#  80424516.9286213,
#  72446804.95205216,
#  66525525.12337575,
#  59674364.06173548,
#  54356081.772221744]

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 6))
plt.plot( wcss, marker='o', linestyle='-', color='b')
plt.title('Elbow Method for Optimal Number of Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

# %%
km=KMeans(n_clusters=4)

# %%
pred=km.fit_predict(df)
# Out:
# C:\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
df['label']=pred

# %%
df.head()
# Out:
#    QUANTITYORDERED  PRICEEACH    SALES  STATUS  PRODUCTLINE  PRODUCTCODE  \
# 0               30      95.70  2871.00       5            1            0
# 1               34      81.35  2765.90       5            1            0
# 2               41      94.74  3884.34       5            1            0
# 3               45      83.26  3746.70       5            1            0
# 4               49     100.00  5205.27       5            1            0
#
#    CITY  COUNTRY  DEALSIZE  label
# 0    42       18         2      3
# 1    56        6         2      3
# 2    52        6         1      3
# 3    53       18         1      3
# 4    59       18         1      0
